# %% [markdown]
# # Density Estimation Techniques
# In this lab, you will implement the density estimation techniques we studied in the lecture.
#
# ## Lab Instructions:
# 1. Read the explanation above each requirement very well
# 2. Read the requirement very well before jumping into the code.
# 3. Some requirements have essay questions in them, make sure you do NOT miss them.
# 4. PLEASE Read the hints! They are clear and made to help you complete the requirement as fast as you should
#
# ## About the Lab
# This lab consists of one requirement: [Requirement 1](#Requirement-1) where you implement one of the density estimation methods.
#
# - Refer to the slides whenever you need an equation or a formula.
# - In this lab, you are free to choose your bump function. However, higher accuracies will get a higher grade. <br/>**You will need to justify your choice of that bump function, write that in your own words, do not copy from your colleagues**
# - Feel free to use code from Lab 3.

# %% [markdown]
# ------------------
# ## Density Estimation
#
# ### Recap
#
# In the previous lab, we were introduced to the problem of classification of multivariate data, and we applied Bayes classifier to classify these points.
#
# The Bayes classification rule depends mainly on the class-conditional probability (also known as the class density or class distribution). An accurate method to calculate this distribution is crucial for improving the performance of the classifier.
#
# We built our classifier based on the assumption that this data is multivariate Gaussian random distribution, and we estimated the mean and covariance of this distribution. Finally, a test vector x is classified as (i.e. assigned) the class that maximizes the posterior probability:
#
# $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$
#
# Classification of $x_{test}$ = $argmax_{i} P\big(C_i|x_{test}\big)$ = $argmax_{i} P(x|C_i) * P(C_i)$
#
# * $P(C_i|x_{test})$: Posterior probability
# * $P(x|C_i)$: Class-conditional probability (or distribution)
# * $P(C_i)$: Class apriori probability
#
# **Note that** $P(C_i|x_{test}) \neq P(x_{test}|C_i) * P(C_i)$. Instead,  $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$. However, when we compare multiple classes, the denominator $P(x_{test})$ is independent of the class $i$ and can be regarded as normalizing factor.
#
#
# Where $P(x|C_i)$ is given by the multivariate Gaussian random distribution:
#
# $P(x|C_i) = \mathcal{N}(x; \mu_i, \Sigma_i) = \frac{1}{(2\pi)^{\frac{N}{2}}|\Sigma_i|^{\frac{1}{2}}} exp\big(\frac{-1}{2}(x-\mu_i)^T\Sigma^{-1}_{i}(x-\mu_i)\big)$
#
#
#  ### In this lab
# We will drop off the assumption that $P(x|C_i)$ is drawn out of a Gaussian distribution with mean $\mu$ and covariance $\Sigma$. The distribution is not necessarily Gaussian, yet we will still apply Bayes classifier to classify between data points by assigning each point to the class that maximizes its posterior probability as usual.
#
# #### What will change in Bayes classifier under the new assumption?
# We will answer that for you! $P(x|C_i)$ is no longer equal to the Gaussian distribution as shown
# in the previous equation i.e. we can’t use the Gaussian formula to substitute for $P(x|C_i)$.
#
# #### How will we figure out the unknown distribution (also known as likelihood function)?
# We will answer that for you too! There are three ways for doing so:
#
#     1. Histogram Analysis.
#     2. Naïve Estimator.
#     3. Parzen Window Density Estimator.
#
# All these techniques aim to estimate a density function $P(x|C_i)$ for the training points, and hence you can use the density function to apply Bayes classifier and classify your test points.
# *Refer to the slides to get a brief about these techniques.*

# %% [markdown]
# ## Requirement 1
#
# You are given files **data.csv**, **test_data.csv**, and  **test_data_true.csv**.
#
# **The first file** contains a list of one-dimensional data points and their corresponding classes. The data points were drawn of the
#  distribution shown in Figure 1 (NOTE: It will be your task to estimate this distribution).
#
# ![Screen%20Shot%202020-11-21%20at%2001.01.52-2.png](attachment:Screen%20Shot%202020-11-21%20at%2001.01.52-2.png)
#
# As shown in Figure 1, the points belonging to class 1 were drawn out of the distribution in blue,
# whereas the points belonging to class 2 were drawn out of the distribution in red.
#
# After applying Parzen Window Density Estimator and plotting the estimated distribution for
# both classes, you should observe a similar distribution for each class to the corresponding
# distribution shown in Figure 1.
#
# The format of data files is shown in the following table:
#
# ||Class|Value|
# |-|-|-|
# |Point#1| 1| 5.34|
# |Point#2| 2| 2.73|
# |Point#3| 2| -1.832|
#
# **The second file** contains test points without the associated classes.
#
# The true values for test
# points are found in *test_data_true.csv*.

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# **The first step** is to read and import the training data, test data and the true values for the test data,
# found in the given files respectively.

# %%
def read_data():
    # TODO 1: Read the file 'data.csv' into the variable data.
    #        Convert the matrix data into numpy array and make sure that the values in data is float and not strings.
    # Hint: You already implemented it in Lab 3.
    # Hint: use data = np.asarray(data)
    # Note: data contains both the training data together with labelled classes.
    file = open('data.csv')
    csvreader = csv.reader(file)
    rows = []
    for row in csvreader:
        rows.append(row)
    file.close()
    data = np.array(rows).astype(float)
    return data

# %%
def read_test_data():
    # TODO 2: Read the file 'test_data.csv' and 'test_data_true.csv' into the variables test_data and test_data_true.
    #         Convert the matrix data into numpy arrays and make sure that the values in data is float and not strings.
    # Hint: You already implemented it in Lab 3.
    # Note: test_data contains the unlabelled test class.
    # Note: test_data_true contains the actual classes of the test instances, which you will compare
    #       against your predicted classes.
    ############################################# Read test_data ###################################################
    test_data = []
    file = open('test_data.csv')
    csvreader = csv.reader(file)
    #header = next(csvreader)
    test_rows = []
    for row in csvreader:
        test_rows.append(row)
    file.close()
    test_data = np.array(test_rows).astype(float)
    
    ############################################# Read test_data_true ##############################################
    test_data_true = []
    file = open('test_data_true.csv')
    csvreader = csv.reader(file)
    #header = next(csvreader)
    test_true_rows = []
    for row in csvreader:
        test_true_rows.append(row)
    file.close()
    test_data_true = np.array(test_true_rows).astype(float)
    return test_data, test_data_true

# %%
data = read_data()
test_data, test_data_true = read_test_data()

# %% [markdown]
# **The second step** is to choose a suitable bump function (Parzen window), and find the optimal value of `h`
# for the bump function for each class.
#
# First, fill in the function `calculate_h_optimal()`. Pass the convenient parameters.

# %%
# Note: Pass the suitable parameters
def calculate_h_optimal(N,M,sigma_s):
    # TODO 3: Calculate the optimal value for the bandwidth (h) of Parzen window (or the bump function you are going
    #  to compute). Pass the suitable parameters. 
    # Hint: Refer to the slides to find out the equation of computing h optimal and know which parameters you should pass.
    sigma = np.sum(sigma_s)
    exp_1 = (4/((N+2)*M))
    exp_2 = (1/(N+4))
    h_i = sigma*(exp_1**exp_2)
    h = h_i/N
    
    return h

# %% [markdown]
# Second, implement the bump function (i.e. Parzen window). You should compute
# the bump function for any x, given a point p and an optimal value for h.
#
# Y = F(x), where x represents the domain of the function or equivalently some
# values to compute the bump function at, y represents the output of the bump
# function and F represents the bump function.
#
# **Notes:** You should vectorise this (i.e. your function should work if x were a single data point or a vector of M data points).

# %%
def bump_function(point, x, h):
    # TODO 4: Implement the bump function phi(x) at point p with bandwidth h. Note that x can be a scalar or a vector.
    # NOTE: Your solution should be vectorized.
    exp_1 = 1/(np.sqrt(2*np.pi)*h)
    exp_2 = np.exp(-((x - point)**2) / (2 *(h**2)))
    f = exp_1 * exp_2
    
    return f

# %% [markdown]
# **Question 1** What are the criteria of choosing bump function?

# %%
'''
    Your Answer: Does not have to be Gaussian, where any suitable bump function should integrates to 1 (from -∞ to ∞).
'''
# Out:
# '\n    Your Answer: Does not have to be Gaussian, where any suitable bump function should integrates to 1 (from -∞ to ∞).\n'

# %% [markdown]
# **Question 2** Justify why you choose that as your bump function. Do you expect it to enhance accuracy? Why?
#
# Write everything you would like to say

# %%
'''
    Your Answer: - As this bump function (Gaussian) is more effective to the point itself (decreasing weight of other points).
                 - Guassian distribution is more smooth than any other functions like rect (Histogram) and the Naïve Estimator due to sharp edges.
'''
# Out:
# '\n    Your Answer: - As this bump function (Gaussian) is more effective to the point itself (decreasing weight of other points).\n                 - Guassian distribution is more smooth than any other functions like rect (Histogram) and the Naïve Estimator due to sharp edges.\n'

# %% [markdown]
# **At this point,** you need to iterate over the training points and apply the bump
# function for every training point.\
# The density estimate will be the accumulation (i.e. the sum) of the output of these bump functions.
#
# We first need to generate the x vector which represents the possible values for the one
# dimensional feature we have. You can find the minimum and maximum possible values for x among the training data, and generate a range of points which will represent your one-dimensional axis.
#
#                             x = np.linspace(min_x, max_x, number_of_axis_points)
#
# Here, `min_x` represents the minimum value for the feature x, `max_x` represents the
# maximum value for the feature x, and `number_of_axis_points` represents the
# resolution of the scale (or how many points should be included between these two
# limits).

# %%
# TODO 5: Construct x-axis that will be used in density estimation.
min_x = np.min(data[:,1])
max_x = np.max(data[:,1])
number_of_axis_points = 10000
x = np.linspace(min_x, max_x, number_of_axis_points)

# %% [markdown]
# Now we need to compute the desnsities for each class. Remember that the density estimate represents `P(x|Ci)`
#
# We start by computing h_optimal for each class we have:

# %%
# TODO 6: Calculate the optimal h for each class. 
# (Warning: Do not use for loops. Use vectorization, broadcasting and masking).
Y = data[:,0]
class1_data = data[Y == 1,1]
class2_data = data[Y == 2,1]

mean1 = np.mean(class1_data)
mean2 = np.mean(class2_data)

sigma1 = np.cov(class1_data)
sigma2 = np.cov(class2_data)

N=1
h1 = calculate_h_optimal(N,len(class1_data),np.sqrt(sigma1))
h2 = calculate_h_optimal(N,len(class2_data),np.sqrt(sigma2))
print(h1)
print(h2)
#h1 = calculate_h_optimal
#h2 = calculate_h_optimal
# Out:
# 0.9195646584889945
# 1.3974291343006038

# %% [markdown]
# We then use these h_optimals to calculate the density functions:

# %%
# TODO 7: Calculate the probability density function p(x|C1) and p(x|C2) for each value on the constructed x-axis
pxgivenC1 = np.zeros(number_of_axis_points)  # class 1
pxgivenC2 = np.zeros(number_of_axis_points)  # class 2

for p in class1_data:
    pxgivenC1 += bump_function(x,p,h1)
for p in class2_data:
    pxgivenC2 += bump_function(x,p,h2)

pxgivenC1 /= len(class1_data)
pxgivenC2 /= len(class2_data)

# %% [markdown]
# Now we need to visualize how well are we estimating the densities.\
# Let's plot the density estimates for the two classes that we computed in **ONE PLOT** with **DIFFERENT
# COLORS.** This is an ordinary plot.
#
# **Check your plot result**:\
# Is it similar to Figure 1? If yes, proceed to question 5. If no, unfortunately you have
# done something wrong. Think: Do you need another bump function? Do you need more points?
#
# **FAQ:** What do you mean by two classes in one plot with different colors?\
# Answer: The two classes are overlaid together in one plot (such as Figure 1) with
# different colors (red and blue). We can’t be any more specific :")

# %%
# plot the estimated densities
# TODO 8: Plot the two densities P(x|C1) and P(x|C2) on the same plot. use plt.plot(..)
plt.plot(x, pxgivenC1, 'b', x, pxgivenC2, 'r')
plt.show()

# %% [markdown]
# It’s time to classify the test points. You know what to do already! Given the points in
# the test file, it’s required to classify each point whether it belongs to class 1 or 2 by
# applying Bayes classifier. Report the accuracy of your classifier by comparing with
# the true values found in the third file.
#
# Hint: It’s not as easy as it looks like, there’s a trick here. Be creative in your solution.
# Solutions may differ in this part, and this may lead to varying accuracies between
# students.\
# *May the odds be in your favor and you get the highest accuracy!*

# %%
# TODO 9: Calculate the aprior probabilities p(C1) and p(C2).
pc1 = len(class1_data)/len(data)
pc2 = len(class2_data)/len(data)

# %%
# TODO 10: Calculate the posterior probabilities p(C1|x) and p(C2|x) for all values in x.
pc1GivenX = pxgivenC1 * pc1
pc2GivenX = pxgivenC2 * pc2

# %%
def find_nearest(array, value):
    '''
    This function finds which element in array is equal to value. If not found, it returns the nearest (or closest)
    element in the array to value.
    :param array: An array of values to search in.
    :param value: A value to select from the array.
    :return: The index of the found element in the array. If not found, it returns the index of the closest element.
    '''
    ## DO NOT Change Code ##
    array = np.asarray(array)
    index = (np.abs(array - value)).argmin()
    return index

# %%
# TODO 11: Compute the accuracy of your classifier.
accuracy = 0
for idx, point in enumerate(test_data):
    i = find_nearest(x,point)
    p1 = pc1GivenX[i]
    p2 = pc2GivenX[i]
    classification = 1.0 if (p1>p2) else 2.0
    if classification == test_data_true[idx]:
        accuracy+=1
    print("for point:", point, "the classification: ", classification)
# Out:
# for point: [11.23317053] the classification:  2.0
# for point: [17.05956066] the classification:  2.0
# for point: [20.] the classification:  2.0
# for point: [-3.1319357] the classification:  1.0
# for point: [8.80189039] the classification:  2.0
# for point: [6.] the classification:  1.0
# for point: [0.14068925] the classification:  1.0
# for point: [3.00817328] the classification:  1.0
# for point: [5.] the classification:  1.0
# for point: [1.45768636] the classification:  1.0
# for point: [23.] the classification:  2.0
# for point: [2.47872809] the classification:  1.0
# for point: [-2.89862058] the classification:  1.0
# for point: [2.88643351] the classification:  1.0
# for point: [10.98552329] the classification:  2.0
# for point: [10.50195166] the classification:  2.0
# for point: [21.09271188] the classification:  2.0
# for point: [0.75791643] the classification:  1.0
# for point: [-4.01268405] the classification:  1.0
# for point: [-2.83807276] the classification:  1.0
# for point: [13.21236831] the classification:  2.0
# for point: [18.] the classification:  2.0
# for point: [4.05353281] the classification:  1.0
# for point: [2.96020771] the classification:  1.0
# for point: [0.58233444] the classification:  1.0
# for point: [12.57948628] the classification:  2.0
# for point: [-2.74915887] the classification:  1.0
# for point: [6.] the classification:  1.0
# for point: [0.82682678] the classification:  1.0
# for point: [19.] the classification:  2.0
# for point: [24.] the classification:  2.0
# for point: [17.] the classification:  2.0
# for point: [-2.09584422] the classification:  1.0
# for point: [0.25830443] the classification:  1.0
# for point: [12.40784468] the classification:  2.0
# for point: [1.05165023] the classification:  1.0
# for point: [7.] the classification:  2.0
# for point: [11.45179533] the classification:  2.0
# for point: [2.164882] the classification:  1.0
# for point: [4.02542079] the classification:  1.0
# for point: [8.05461435] the classification:  2.0
# for point: [14.05050832] the classification:  2.0
# for point: [8.] the classification:  2.0
# for point: [24.] the classification:  2.0
# for point: [12.68840762] the classification:  2.0
# for point: [11.15645936] the classification:  2.0
# for point: [12.26910594] the classification:  2.0
# for point: [22.] the classification:  2.0
# for point: [26.] the classification:  2.0
# for point: [12.87348982] the classification:  2.0
# for point: [0.20484083] the classification:  1.0
# for point: [10.29874226] the classification:  2.0
# for point: [16.54259653] the classification:  2.0
# for point: [11.53617634] the classification:  2.0
# for point: [-3.03364717] the classification:  1.0
# for point: [8.] the classification:  2.0
# for point: [7.] the classification:  2.0
# for point: [1.20409131] the classification:  1.0
# for point: [12.61722858] the classification:  2.0
# for point: [10.87113771] the classification:  2.0
# for point: [6.] the classification:  1.0
# for point: [12.6902838] the classification:  2.0
# for point: [10.] the classification:  2.0
# for point: [12.55888984] the classification:  2.0
# for point: [23.] the classification:  2.0
# for point: [-0.08566497] the classification:  1.0
# for point: [16.] the classification:  2.0
# for point: [7.26973899] the classification:  2.0
# for point: [3.27958364] the classification:  1.0
# for point: [3.] the classification:  1.0
# for point: [-3.08259835] the classification:  1.0
# for point: [17.] the classification:  2.0
# for point: [8.] the classification:  2.0
# for point: [0.70514228] the classification:  1.0
# for point: [0.54934094] the classification:  1.0
# for point: [-2.30346518] the classification:  1.0
# for point: [0.00269114] the classification:  1.0
# for point: [0.30951908] the classification:  1.0
# for point: [17.] the classification:  2.0
# for point: [11.02945226] the classification:  2.0
# for point: [11.1514939] the classification:  2.0
# for point: [-1.06087991] the classification:  1.0
# for point: [3.7830825] the classification:  1.0
# for point: [1.57114863] the classification:  1.0
# for point: [2.] the classification:  1.0
# for point: [18.] the classification:  2.0
# for point: [10.18354832] the classification:  2.0
# for point: [3.] the classification:  1.0
# for point: [-0.1242808] the classification:  1.0
# for point: [-0.69722827] the classification:  1.0
# for point: [-2.07390303] the classification:  1.0
# for point: [-1.00875744] the classification:  1.0
# for point: [18.] the classification:  2.0
# for point: [10.1417458] the classification:  2.0
# for point: [2.92657058] the classification:  1.0
# for point: [0.44461327] the classification:  1.0
# for point: [11.33405643] the classification:  2.0
# for point: [11.70363968] the classification:  2.0
# for point: [4.] the classification:  1.0
# for point: [-2.30025345] the classification:  1.0
# for point: [7.34815006] the classification:  2.0
# for point: [21.] the classification:  2.0
# for point: [10.] the classification:  2.0
# for point: [7.66297305] the classification:  2.0
# for point: [11.63367714] the classification:  2.0
# for point: [0.58892778] the classification:  1.0
# for point: [-3.61507106] the classification:  1.0
# for point: [27.] the classification:  2.0
# for point: [22.] the classification:  2.0
# for point: [8.07488659] the classification:  2.0
# for point: [23.] the classification:  2.0
# for point: [-4.08280822] the classification:  1.0
# for point: [9.43411682] the classification:  2.0
# for point: [3.] the classification:  1.0
# for point: [10.12723117] the classification:  2.0
# for point: [14.92710767] the classification:  2.0
# for point: [14.50605535] the classification:  2.0
# for point: [14.] the classification:  2.0
# for point: [12.54056379] the classification:  2.0
# for point: [-2.47909567] the classification:  1.0
# for point: [5.] the classification:  1.0
# for point: [16.02740065] the classification:  2.0
# for point: [18.] the classification:  2.0
# for point: [21.] the classification:  2.0
# for point: [6.] the classification:  1.0
# for point: [5.96186488] the classification:  1.0
# for point: [-3.62306587] the classification:  1.0
# for point: [11.21888551] the classification:  2.0
# for point: [3.08339561] the classification:  1.0
# for point: [12.58587476] the classification:  2.0
# for point: [4.19271009] the classification:  1.0
# for point: [6.7144799] the classification:  2.0
# for point: [10.66940815] the classification:  2.0
# for point: [-4.21851547] the classification:  1.0
# for point: [5.] the classification:  1.0
# for point: [1.2606314] the classification:  1.0
# for point: [11.62684981] the classification:  2.0
# for point: [3.] the classification:  1.0
# for point: [12.19238575] the classification:  2.0
# for point: [6.] the classification:  1.0
# for point: [3.] the classification:  1.0
# for point: [10.] the classification:  2.0
# for point: [0.2558917] the classification:  1.0
# for point: [7.0282671] the classification:  2.0
# for point: [17.] the classification:  2.0
# for point: [5.14319629] the classification:  1.0
# for point: [18.] the classification:  2.0
# for point: [6.02796066] the classification:  1.0
# for point: [-3.34137853] the classification:  1.0
# for point: [7.] the classification:  2.0
# for point: [0.75393221] the classification:  1.0
# for point: [0.24945848] the classification:  1.0
# for point: [1.05078378] the classification:  1.0
# for point: [-0.48441629] the classification:  1.0
# for point: [11.29841459] the classification:  2.0
# for point: [4.] the classification:  1.0
# for point: [7.] the classification:  2.0
# for point: [1.72559541] the classification:  1.0
# for point: [-0.1794073] the classification:  1.0
# for point: [5.] the classification:  1.0
# for point: [8.03921633] the classification:  2.0
# for point: [24.02866415] the classification:  2.0
# for point: [19.] the classification:  2.0
# for point: [1.65899063] the classification:  1.0
# for point: [-0.45788016] the classification:  1.0
# for point: [1.10658875] the classification:  1.0
# for point: [1.3551024] the classification:  1.0
# for point: [-0.81386454] the classification:  1.0
# for point: [8.81410816] the classification:  2.0
# for point: [16.33216685] the classification:  2.0
# for point: [0.4595173] the classification:  1.0
# for point: [9.9331065] the classification:  2.0
# for point: [-3.68741442] the classification:  1.0
# for point: [-4.47648462] the classification:  1.0
# for point: [7.] the classification:  2.0
# for point: [8.31126872] the classification:  2.0
# for point: [10.05519059] the classification:  2.0
# for point: [0.43523655] the classification:  1.0
# for point: [2.13300233] the classification:  1.0
# for point: [-5.02988705] the classification:  1.0
# for point: [13.] the classification:  2.0
# for point: [12.85747698] the classification:  2.0
# for point: [5.28177256] the classification:  1.0
# for point: [5.] the classification:  1.0
# for point: [7.33484908] the classification:  2.0
# for point: [12.71867117] the classification:  2.0
# for point: [21.] the classification:  2.0
# for point: [21.] the classification:  2.0
# for point: [9.16027171] the classification:  2.0
# for point: [6.] the classification:  1.0
# for point: [4.62602077] the classification:  1.0
# for point: [0.12559417] the classification:  1.0
# for point: [14.03434757] the classification:  2.0
# for point: [6.] the classification:  1.0
# for point: [8.] the classification:  2.0
# for point: [14.38203358] the classification:  2.0
# for point: [9.46220191] the classification:  2.0
# for point: [-3.3183221] the classification:  1.0
# for point: [0.26347067] the classification:  1.0
# for point: [2.91977604] the classification:  1.0
# for point: [-0.9989825] the classification:  1.0
# for point: [2.3222054] the classification:  1.0
# for point: [12.32218596] the classification:  2.0
# for point: [-2.86584969] the classification:  1.0
# for point: [1.22295838] the classification:  1.0
# for point: [15.21071041] the classification:  2.0
# for point: [3.] the classification:  1.0
# for point: [2.60391062] the classification:  1.0
# for point: [11.01543288] the classification:  2.0
# for point: [8.79677773] the classification:  2.0
# for point: [9.96530807] the classification:  2.0
# for point: [-2.26811141] the classification:  1.0
# for point: [1.96440094] the classification:  1.0
# for point: [24.] the classification:  2.0
# for point: [12.3028623] the classification:  2.0
# for point: [-1.30754999] the classification:  1.0
# for point: [-1.73572345] the classification:  1.0
# for point: [-3.30619515] the classification:  1.0
# for point: [3.57831656] the classification:  1.0
# for point: [-0.16584155] the classification:  1.0
# for point: [-0.31294768] the classification:  1.0
# for point: [28.] the classification:  2.0
# for point: [4.] the classification:  1.0
# for point: [7.65621935] the classification:  2.0
# for point: [11.49685595] the classification:  2.0
# for point: [12.06177687] the classification:  2.0
# for point: [-0.69137205] the classification:  1.0
# for point: [0.0823093] the classification:  1.0
# for point: [5.54159517] the classification:  1.0
# for point: [11.7568794] the classification:  2.0
# for point: [-0.94813657] the classification:  1.0
# for point: [-3.75851082] the classification:  1.0
# for point: [0.71566614] the classification:  1.0
# for point: [0.73113459] the classification:  1.0
# for point: [0.3066048] the classification:  1.0
# for point: [-3.97187382] the classification:  1.0
# for point: [10.54936315] the classification:  2.0
# for point: [16.] the classification:  2.0
# for point: [0.34323948] the classification:  1.0
# for point: [15.51308856] the classification:  2.0
# for point: [-0.66220667] the classification:  1.0
# for point: [15.] the classification:  2.0
# for point: [12.9985909] the classification:  2.0
# for point: [11.04217013] the classification:  2.0
# for point: [23.] the classification:  2.0
# for point: [12.8797895] the classification:  2.0
# for point: [3.] the classification:  1.0
# for point: [14.21662099] the classification:  2.0
# for point: [7.43832513] the classification:  2.0
# for point: [2.20589722] the classification:  1.0
# for point: [0.32997595] the classification:  1.0
# for point: [11.07987236] the classification:  2.0
# for point: [10.02173328] the classification:  2.0
# for point: [2.38062012] the classification:  1.0
# for point: [3.3330299] the classification:  1.0
# for point: [11.89994502] the classification:  2.0
# for point: [1.01142256] the classification:  1.0
# for point: [-1.91595289] the classification:  1.0
# for point: [3.85864511] the classification:  1.0
# for point: [0.28307264] the classification:  1.0
# for point: [7.6836647] the classification:  2.0
# for point: [0.20875098] the classification:  1.0
# for point: [18.] the classification:  2.0
# for point: [0.85843411] the classification:  1.0
# for point: [22.] the classification:  2.0
# for point: [11.76751242] the classification:  2.0
# for point: [7.05871167] the classification:  2.0
# for point: [15.50233457] the classification:  2.0
# for point: [11.4720431] the classification:  2.0
# for point: [9.] the classification:  2.0
# for point: [-2.35799224] the classification:  1.0
# for point: [14.13129143] the classification:  2.0
# for point: [0.18528955] the classification:  1.0
# for point: [12.74147371] the classification:  2.0
# for point: [7.11309654] the classification:  2.0
# for point: [10.52560801] the classification:  2.0
# for point: [12.40589522] the classification:  2.0
# for point: [1.10819638] the classification:  1.0
# for point: [19.] the classification:  2.0
# for point: [6.56989806] the classification:  2.0
# for point: [11.21981129] the classification:  2.0
# for point: [12.52687565] the classification:  2.0
# for point: [4.] the classification:  1.0
# for point: [4.31281709] the classification:  1.0
# for point: [12.08183967] the classification:  2.0
# for point: [11.] the classification:  2.0
# for point: [0.04872458] the classification:  1.0
# for point: [5.73653332] the classification:  1.0
# for point: [6.33959269] the classification:  2.0
# for point: [4.] the classification:  1.0
# for point: [-2.60030245] the classification:  1.0
# for point: [11.30717985] the classification:  2.0
# for point: [19.96658861] the classification:  2.0
# for point: [-0.98647836] the classification:  1.0
# for point: [13.18115383] the classification:  2.0
# for point: [12.45555028] the classification:  2.0
# for point: [8.33343959] the classification:  2.0
# for point: [23.] the classification:  2.0
# for point: [15.03570947] the classification:  2.0
# for point: [9.89437578] the classification:  2.0

# %%
print("Accuracy = ", accuracy*100/len(test_data_true), "%")
# Out:
# Accuracy =  91.0 %
